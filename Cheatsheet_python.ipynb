# %% [markdown]
# # CheatSheet
#
# ## Python String
#
# 1. [:] or [0:-1] --> Entire String
# 2. [start:end:step]
# 3. [-3:] --> Last three characters
# 4. [-6:-2] --> 4 strings from last two
# 5. [::7] --> 7 steps from start to end
# 6. [-1::-1] or [::-1] --> reverse the string
#
# ### String & Functions
# 1. len() --> length of string ex. len("string")
# 2. split --> split the string and save in list. string.split(arguments)
# 3. join --> opposite of split. ','.join(list)
# 4. string.startswith("ALL")
# 5. string.endswith("ALL")
# 6. string.find("ALL")
# 7. string.rfind("ALL") - last find word offset
# 8. string.count("ALL")
# 9. string.isalnum()
# 10. string.strip(',') - strip matched patterns at last
# 11. string.capitalize() - capitalize first word
# 12. string.title() - capitalize first letter of all word
# 13. string.upper() - capitalize all words
# 14. string.lower() -
# 15. string.swapcase() -
# 16. string.center(30) - centered the string
# 17. string.ljust(30) - left justify
# 18. string.rjust(30) - right justify
# 19. var.replace('duck', 'suck', 100)
#
# ### List --> represent by s here
# 1. s=[] or list() --> To creat an empty list
# #### Most of the string functions works the same with list also.
# 2. s.append('anything') --> for adding any elements in list s
# 3. s.extend(list) or s += other_list --> extend items of list s or add items in the list s
# 4. s.append(other_list) --> add other_list inside the list s
# 5. s.insert(5, 'item') --> add item in the specific offset
# 6. del s[-1] --> Delete last element from the list and del will delete item with offset
# 7. s.remove('item') --> delete item by value
# 8. s.pop(offset) --> get it and remove last item or specific item with
# 9. s.index('item')--> get offset of an item
# 10. 'item' in s --> test value in
# 11. s.count('item') --> count an item in list
# 12. ', '.join(s) --> join list as string
# ### sort -->
# 1. t = sorted(s) --> sort and save, doesn't change the items of list s
# 2. s.sort() --> sort and change items of list s
# #### Copy lists
# 1. a = b --> same elements but depend on first list
# 2. b=a.copy() --> copy elements individualy
# 3. c=list(a) --> copy elements individualy
# 4. d=a[:] --> copy elements individualy
# ### Tuple --> We cannot modified tuple
# 1. () --> empty Tuple
# 2. t=('first', 'second', 'third')
# 3. a,b,c=t --> tuple unpacking, right now value of a is 'first', b is 'second' and c is 'third'. To interchange the value
# 4. a,b=b,a --> interchange the value
#
# - Tuples use less space
# - use tuples as dictionary keys
# - Named tuples can be a simple alternative objects
# - function arguments are passed as tuples
#
# ### Dictionary - {}
# - we can call it an associative array, hashes or hashmaps
# - d={'key':'value'}
# - d will print the dictionary
# - s=[['a', 'b'], ['c', 'd'], ['e', 'f']] then convert it by dict(s)
# - t=[('a', 'b'), ('c', 'd'), ('e', 'f')] then convert it by dict(t)
# - l=(['a', 'b'], ['c', 'd'], ['e', 'f']) then convert it by dict(l)
# - str=['ab', 'cd', 'ef'] then convert it by dict(str)
# - stuple=('ab', 'cd', 'ef') then convert it by dict(stuple)
# ### Add or change item by key
# - d={'a':'b', 'c':'d', 'e':'f'}
# - d['a'] --> get an item by key
# - d.get('key','Error msg') --> get the value of print the msg otherwise print none, blank
# - d.keys() --> show all keys
# - list(d.keys()) --> all keys in list output
# - d.values() --> show all values of keys
# - list(d.values()) --> all values in list output
# - list(d.items()) --> all items in list format
# - d['g']='h' --> Add an item or if exists then change the item
# - dict1.update(dict2) --> combine two dictionary
# - del dict['key'] --> Delete an Item by Key
# - dict.clear() - clear the dictionary
# - 'key' in dict --> test for key
# #### copy dictionary
# - original_dict = dict.copy()
# ### use of dict in loops and conditions
# - drinks = {
#     ...     'martini': {'vodka', 'vermouth'},
#     ...     'black russian': {'vodka', 'kahlua'},
#     ...     'white russian': {'cream', 'kahlua', 'vodka'},
#     ...     'manhattan': {'rye', 'vermouth', 'bitters'},
#     ...     'screwdriver': {'orange juice', 'vodka'}
#     ...    }
# - for name, contents in drinks.items():
#     -  if 'vodka' in contents:
# - for name, contents in drinks.items():
#     - if 'vodka' in contents and not ('vermouth' in contents or 'cream' in contents):
#         - print(name)
# - for name, contents in drinks.items():
#     -  if contents & {'vermouth', 'orange juice'}:
#         - print(name)
# - for name, contents in drinks.items():
#     -  if 'vodka' in contents and not contents & {'vermouth', 'cream'}:
#         - print(name)
# ### Sets - --> & is for intersection --> | for union --> ^ or symmetric_difference() --> - or difference() for difference --> using <= or issubset() --> uses >= or issuperset()
# - A set is like a dictionary with its values thrown away, leaving only the keys.
# - empty_set = set() --> creat an empty set
# - set({'a':'b', 'c':'d'}) --> It will gives only keys
#
# ## Operators
# - equality ==
# - inequality !=
# - less than <
# - less than or equal <=
# - greater than >
# - greater than or equal >=

# %% [markdown]
# # Intermediate Python
#
# ### zip() --> iterating over multiple sequences in parallel
# #### ex1.
# - days = ['Monday', 'Tuesday', 'Wednesday']
# - fruits = ['banana', 'orange', 'peach']
# - drinks = ['coffee', 'tea', 'beer']
# - desserts = ['tiramisu', 'ice cream', 'pie', 'pudding']
# - for day, fruit, drink, dessert in zip(days, fruits, drinks, desserts): ... print(day, ": drink", drink, "- eat", fruit, "- enjoy", dessert)
# Monday : drink coffee - eat banana - enjoy tiramisu
# #### ex2.
# - english = 'Monday', 'Tuesday', 'Wednesday'
# - french = 'Lundi', 'Mardi', 'Mercredi'
# - list( zip(english, french) ) --> output in list
# - dict( zip(english, french) ) --> output in dict
#
# ### range() --> range( start, stop, step )
# - for x in range(2, -1, -1):
#
# ## Comprehensions
# ### List comprehensions
# #### one way
# - number_list = []
# - for number in range(1, 6):
#     - number_list.append(number)
# - number_list
# [1,2,3,4,5]
# #### second way
# - number_list = list(range(1, 6))
# #### comprehensive way
# number_list = [number for number in range(1,6)]
# #### other way to use comprehensions
# - number_list = [number-1 for number in range(1,6)]
# - a_list = [number for number in range(1,6) if number % 2 == 1]
# #### ex.
# - rows = range(1,4)
# - cols = range(1,3)
# - cells = [(row, col) for row in rows for col in cols]
#     - for cell in cells:
#         - print(cell)
# - for row, col in cells:
#     - print(row, col)
# ### Dictionary Comprehensions - { key_expression : value_expression for expression in iterable }
# - word = 'letters'
# - letter_counts = {letter: word.count(letter) for letter in word}
# - letter_counts
#     - {'l': 1, 'e': 2, 't': 2, 'r': 1, 's': 1}
# - ex. 2
# - word = 'letters'
# - letter_counts = {letter: word.count(letter) for letter in set(word)}
# -  letter_counts
#     - {'t': 2, 'l': 1, 'e': 2, 'r': 1, 's': 1}
# ### Set Comprehensions - { expression for expression in iterable }
# - a_set = {number for number in range(1,6) if number % 3 == 1}
# - a_set
#     - {1, 4}
# ### Generator Comprehensions - same for tuple
# - number_thing = (number for number in range(1, 6))
# - type(number_thing)
# - <class 'generator'>
#
# ## Functions
# #### Way to defind function
# - def myfunc():
#     - pass
#     - return
# -
# #### None is different from False and will use when we have to check that o is false or None in funtion.
# ### Positional Arguments - function arguments in a manner that’s will not change their position
# - def menu(wine, entree, dessert):
#     -  return {'wine': wine, 'entree': entree, 'dessert': dessert}
# ### Keyword Arguments - To avoid positional argument confusion,
# - menu(entree='beef', dessert='bagel', wine='bordeaux')
# ### Specify Default Parameter Values
# - def menu(wine, entree, dessert='pudding'):
#     - return {'wine': wine, 'entree': entree, 'dessert': dessert}
# #### ex.
# - def buggy(arg, result=[]):
#     - result.append(arg)
#     - print(result)
# #### but the issue in the above is that the second time, result still has one item from the previous call
# - rewritten like that
# - def works(arg):
#     -  result = []
#     -  result.append(arg)
#     -  return result
# #### OR
# def nonbuggy(arg, result=None):
#     - if result is None:
#         - result = []
#         - result.append(arg)
#         - print(result)
# ### Gather Positional Arguments with *
# - def print_args(*args):
#     -  print('Positional argument tuple:', args)
# - def print_more(required1, required2, *args):
#     - print('Need this one:', required1)
#     - print('Need this one too:', required2)
#     - print('All the rest:', args)
# ### Gather Keyword Arguments with **
# - def print_kwargs(**kwargs):
#     - print('Keyword arguments:', kwargs)
# ### Docstrings - Readability counts
# - def echo(anything):
#     - 'echo returns its input argument'
#     - return anything
# ### Functions Are First-Class Citizens -
# - def run_something_with_args(func, arg1, arg2):
#     - func(arg1, arg2)
# ### Inner Functions - define a function within another function
# - def outer(a, b):
#     - def inner(c, d):
#         - return c + d
#     - return inner(a, b)
# ### Closures - An inner function can act as a closure. This is a function that is dynamically generated by another function and can both change and remember the values of variables that were created outside the function.
# ### Lambda
# - def edit_story(words, func):
# -     for word in words:
# -         print(func(word))
# - stairs = ['thud', 'meow', 'thud', 'hiss']
# - edit_story(stairs, lambda word: word.capitalize() + '!')
# ### Generators - def() and yield
# ### Decorators - @
# ### Uses of _ and __ in Names
# def amazing():
#     - '''This is the amazing function.
#     - Want to see it again?'''
#     - print('This function is named:', amazing.__name__)
#     - print('And its docstring is:', amazing.__doc__) ...
# > amazing()
# This function is named: amazing
# And its docstring is: This is the amazing function.
# Want to see it again?
# ## Handle Errors with try and except
# short_list = [1, 2, 3]
# position = 5
# try:
#     - short_list[position]
# except:
#     - print('Need a position between 0 and', len(short_list)-1, ' but got', ... position)
# #### except exceptiontype as name

# %% [markdown]
# # Advanced Python
#
# ### Module Search Path - Python look for files to import
# - import sys
# - for place in sys.path:
#     - print(place)
# ### Handle Missing Keys with setdefault() and defaultdict()
# #### We use get() to not raise an exception in dictionary
# #### setdefault() - It checks if a key is present or not, if not then set the key with given value
# - periodic_table = {'Hydrogen': 1, 'Helium': 2}
# - carbon = periodic_table.setdefault('Carbon', 12) -> so if carbon isn't present in dict then set the value of carbin to 12
# #### defaultdict() - It is similar, but specifies the default value for any new key up front, when the dictionary is created. We can pass any function like int(), dict(), list() or any func. we created.
# - from collections import defaultdict
# - periodic_table = defaultdict(int)
# - periodic_table['Hydrogen'] = 1
# - => periodic_table['Lead'] --> As Lead key is not in periodic_table dict so it defaultdict() assigns 0 bydefault.
# - 0
# ### Counter() - Count items
# - from collections import Counter
# - breakfast = ['spam', 'spam', 'eggs', 'spam']
# - breakfast_counter = Counter(breakfast)
# - breakfast_counter
# - => Counter({'spam': 3, 'eggs': 1})
# ####  most_common() - returns all elements in descending order, or just the top count elements if given a count
# - breakfast_counter.most_common()
# - => [('spam', 3), ('eggs', 1)]
# - breakfast_counter.most_common(1)
# - => [('spam', 3)]
# ### OrderedDict() - Order by key - An OrderedDict() remembers the order of key addition and returns them in the same order from an iterator.
# - from collections import OrderedDict
# - quotes = OrderedDict([('Moe', 'A wise guy, huh?'),('Larry', 'Ow!'),('Curly', 'Nyuk nyuk!'),])
# - for stooge in quotes:
# - print(stooge)
# - => Moe
# - => Larry
# - => Curly
# ### Stack + Queue == deque -> double-ended queue
# 1. append() :- This function is used to insert the value in its argument to the right end of deque.
# 2. appendleft() :- This function is used to insert the value in its argument to the left end of deque.
# 3. pop() :- This function is used to delete an argument from the right end of deque.
# 4. popleft() :- This function is used to delete an argument from the left end of deque.
# 5. extend():
# 6. extendleft():
# - import collections
# - de = collections.deque([1,2,3])
# - de.append(4)  and so on...
# ### Iterate over Code Structures with itertools
# - import itertools
# - for item in itertools.chain([1, 2], ['a', 'b']):
#     - print(item)
# #### cycle() is an infinite iterator, cycling through its arguments:
# - import itertools
# - for item in itertools.cycle([1, 2]):
#     - print(item)
# - accumulate() calculates accumulated values. By default, it calculates the sum
# - import itertools
# - for item in itertools.accumulate([1, 2, 3, 4]):
#     - print(item) --> output will be 1,3,6,10
# - def multiply(a, b):
#     - returna*b
# - for item in itertools.accumulate([1, 2, 3, 4], multiply):
#     - print(item) --> output will be 1,2,6,24
# ### Print Nicely with pprint() - > pretty printer
# - from pprint import pprint
# - quotes = OrderedDict([('Moe', 'A wise guy, huh?'),('Larry', 'Ow!'),('Curly', 'Nyuk nyuk!'),])
# - print(quotes) --> OrderedDict([('Moe', 'A wise guy, huh?'), ('Larry', 'Ow!'), ('Curly', 'Nyuk nyuk!')])
# - pprint(quotes) -->
# -       {'Moe': 'A wise guy, huh?',
# -      'Larry': 'Ow!',
# -      'Curly': 'Nyuk nyuk!'}

# %% [markdown]
# # Objects and classes
# ### An object contains both data (variables, called attributes) and code (functions, called methods).
# #### EX.
# - class Person():
#     def __init__(self, name):
#         self.name = name
# - hunter = Person('Elmer Fudd')
# - print('The mighty hunter: ', hunter.name)

# %% [markdown]
# ## Formatting and Regex
#
# ### Two types of formatting are available in Python2 and 3
# #### 1. Old style(%)
# #### 2. New style({})
#
# ### 1. old style:
# - %s string
# - %d decimal integer
# - %x hex integer
# - %o octal integer
# - %f decimal float
# - %e exponential float
# - %g decimal or exponential float %% a literal%
# #### Ex. 1
# - actor = 'Richard Gere'
# - cat = 'Chester'
# - weight = 28
# - "Our cat %s weighs %s pounds" % (cat, weight)
# #### Ex. 2
# - n=42
# - f=7.03
# - s = 'string cheese'
# - --> '%d%f%s'%(n,f,s) --> Format using default width
# - --> '%10d %10f %10s' % (n, f, s) --> Set a minimum field width of 10 characters for each variable, and align them to the right,
# - --> '%-10d %-10f %-10s' % (n, f, s) --> set same width as above with left align
# - --> '%10.4d %10.4f %10.4s' % (n, f, s) --> same field width, but a maximum character width of 4,
# - --> '%.4d %.4f %.4s' % (n, f, s) --> same song as before, but right-aligned
# - --> '%*.*d %*.*f %*.*s' % (10, 4, n, 10, 4, f, 10, 4, s) --> get the field widths from arguments rather than hard-coding them
#
# ### New Style Formatting
# - '{} {} {}'.format(n, f, s) -->
# - '{2} {0} {1}'.format(f, s, n) --> specify the order of arguments
# - '{n} {f} {s}'.format(n=42, f=7.03, s='string cheese') --> The arguments can be a dictionary or named arguments, and the specifiers can include their names
# - d = {'n': 42, 'f': 7.03, 's': 'string cheese'} -->combining our three values into a dictionary
# - --> '{0[n]} {0[f]} {0[s]} {1}'.format(d, 'other') --> {0} is the entire dictionary, whereas {1} is the string 'other' that follows the dictionary
# - '{0:d} {1:f} {2:s}'.format(n, f, s) --> printed their arguments with default formats as old styles
# - '{n:d} {f:f} {s:s}'.format(n=42, f=7.03, s='string cheese') --> use the same values, but as named arguments
# - '{0:10d} {1:10f} {2:10s}'.format(n, f, s) --> Minimum field width 10, right-aligned (default)
# - '{0:>10d} {1:>10f} {2:>10s}'.format(n,f,s) -> Same as the preceding example,but the > char. make the right-alignment
# - '{0:<10d} {1:<10f} {2:<10s}'.format(n, f, s) -> Minimum field width 10, left-aligned
# - '{0:^10d} {1:^10f} {2:^10s}'.format(n, f, s) - Minimum field width 10, centered
# #### There is one change from old-style: the precision value (after the decimal point) still means the number of digits after the decimal for floats, and the maximum number of characters for strings, but you can’t use it for integers
# - '{0:>10.4d} {1:>10.4f} {2:10.4s}'.format(n, f, s) -> upto decimal value
# - '{0:!^20s}'.format('BIG SALE')--> fill character. If you want something other than spaces to pad your output fields, put it right after the :, before any alignment (<, >, ^) or width specifiers
# ## Regular Expressions
# - result = re.match('You', 'Young Frankenstein') -> Here, 'You' is the pattern and 'Young Frankenstein' is the source
# - youpattern = re.compile('You') -> For more complex matches,we can compile pattern first to speed up the match later
# - --> result = youpattern.match('Young Frankenstein')
# ### Options to use in RE
# • match() is not the only way to compare the pattern and source. Here are several other methods you can use:
# • search() returns the first match, if any.
# • findall() returns a list of all non-overlapping matches, if any.
# • split() splits source at matches with pattern and returns a list of the string pieces.
# • sub() takes another replacement argument, and changes all parts of source that are matched by pattern to replacement.
# #### Exact match with match()
# - --> import re
# - --> source = 'Young Frankenstein'
# - --> m = re.match('You', source) # match starts at the beginning of source
# - --> if m: # match returns an object; do this to see what matched
#     - --> print(m.group())
# - m = re.match('^You', source) # start anchor does the same
# - if m:
#     - print(m.group())
# - m = re.match('Frank', source)
# - if m:
#     - print(m.group())

# %%
def amazing():
    '''This is the amazing function.
    Want to see it again?'''
    print('This function is named:', amazing.__name__)
    print('And its docstring is:', amazing.__doc__)
amazing()

# %%
surprise = ['Groucho', 'Chico', 'Harpo']
surprise[-1]=surprise[-1].lower()
surprise[-1] = surprise[-1][::-1]
surprise[-1] = surprise[-1].title()
print(surprise[-1])

# %%
def edit_story(words, func):
    for word in words:
        print(func(word))
stairs = ['thud', 'meow', 'thud', 'hiss']
edit_story(stairs, lambda word: word.capitalize() + '!')

# %%
e2f = {'dog': 'chien', 'cat': 'chat', 'walrus': 'morse'}
print(e2f['walrus'])
f2e={}
for k,v in e2f.items():
    f2e[v]=k
s=set(e2f.values())
print(s)

# %%
life={'animals': {'cats': ['Henri', 'Grumpy', 'Lucy'],'octopi': {},'emus': {}},'plants': {},'other': {}}
print(list (life.keys()))

# %%
#Create dictionary from arbitary key
x=str(input("Enter the number to create dictionary: ")
s={x:x**2 for x in range(1,8)}
print(s)

# %%
#This program is to find number divisible by 7 but not 5 in between 2000 to 3201
l=[]
for i in range(2000, 3201):
    if (i%7==0) and (i%5!=0):
        l.append(str(i))

print(','.join(l))

# %%
#This program is to find factorial of number input by user
num=1
s=int(input("Enter the number for factorial: "))
for i in range(1,s+1):
    num=num*i
print(num)

# %%
s="""It all began back in 2011, when I had just started grad school.
For a class project, my collaborators Natalie Freed, 
Adam Setapen and I created the Telescrapbooks, 
two wirelessly-connected scrapbooks that use electronic sticker modules called I/O stickers—sensors, 
switches, LEDs, motors and speakers—as a way for anyone to build their own custom interactive interfaces."""
t=s.split("\n")
for i in t:
    if "Adam" in i:
        print(i)
s1="""It all began back in 2011, when I had just started grad school."""
s1.strip(' school.')
